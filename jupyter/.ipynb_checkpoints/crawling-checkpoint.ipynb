# %%
# pip install requests beautifulsoup4


import requests

# %%
url = "https://www.semes.com/attach/image/201810/PT20170413184351273_20181012085230_1.jpg"

# %%
res = requests.get(url)

# %%
res.content
# Out:
# b'\xff\xd8\xff\xe1\x00\x18Exif\x00\x00II*\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\xec\x00\x11Ducky\x00\x01\x00\x04\x00\x00\x00P\x00\x00\xff\xe1\x03\x8dhttp://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?> <x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="Adobe XMP Core 5.6-c142 79.160924, 2017/07/13-01:06:39        "> <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <rdf:Description rdf:about="" xmlns:xmpMM="http://ns.adobe.com/xap/1.0/mm/" xmlns:stRef="http://ns.adobe.com/xap/1.0/sType/ResourceRef#" xmlns:xmp="http://ns.adobe.com/xap/1.0/" xmpMM:OriginalDocumentID="xmp.did:b89b262a-2a31-fc4c-b818-fffccc51d48a" xmpMM:DocumentID="xmp.did:B03226A6CDB011E88F388AA018FB5D31" xmpMM:InstanceID="xmp.iid:B03226A5CDB011E88F388AA018FB5D31" xmp:CreatorTool="Adobe Photoshop CC 2018 (Windows)"> <xmpMM:DerivedFrom stRef:instanceID="xmp.iid:d7a7085f-2c00-db4e-8526-37ea98903e42" stRef:documentID="adobe:docid:photoshop:6d846f2c-6646-
# ...

# %%
# j=res.json()['img']

# %%
# 페이지 전체 가지고 오기!
import requests

# %%
url = "https://www.semes.com/product.do?ar_action=listProduct&sch_product_group=SC"

# %%
res = requests.get(url)
# html_txt = requests.get(url).text

# %%
html_txt = res.text

# %%
html_txt
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n \r\n\r\n\r\n<html>\r\n<head>\r\n\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<meta name="robots" content="index, follow" />\r\n<meta name="googlebot" content="index, follow" />\r\n<meta name="description" content="" />\r\n<meta name="keywords" content="" />\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\r\n<link rel="shortcut icon" href="/jsp/html/kor/image/common/favicon.ico"/> \r\n<link rel="stylesheet" type="text/css" href="/css/devF.css" media="all" />\r\n<link rel="stylesheet" type="text/css" href="/css/base.css" media="all" />\r\n<link rel="stylesheet" type="text/css" href="/css/layout.css" media="all" />\r\n<link rel="stylesheet" type="text/css" href="/css/header.css" media="all" />\r\n<link rel="stylesheet" type="text/css" href="/css/copy.css" media="all" />\r\n<link rel="stylesheet" type="text/css" href="/css/page.css" media="all" />\r\n<link rel="stylesheet" type="text/css" href=
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_txt, 'html.parser')

# %%
soup
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="index, follow" name="robots"/>
# <meta content="index, follow" name="googlebot"/>
# <meta content="" name="description"/>
# <meta content="" name="keywords"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/jsp/html/kor/image/common/favicon.ico" rel="shortcut icon"/>
# <link href="/css/devF.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/css/base.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/css/layout.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/css/header.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/css/copy.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/css/page.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/css/board.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
data = soup.select('img[src*=attach]')

# %%
print(data)
# Out:
# [<img alt="LOTUS" src="/attach/image/201810/PT20170413184351273_20181012085230_1.jpg"/>, <img alt="BLUEICE PRIME" src="/attach/image/201810/PT20150914143022237_20181012110720_1.jpg"/>, <img alt="IRIS PRIME" src="/attach/image/201810/PT20150914142745747_20181012120537_1.jpg"/>, <img alt="BLUEICE SPM" src="/attach/image/201810/PT20150923101251740_20181012113449_1.jpg"/>, <img alt="IRIS 12B" src="/attach/image/201810/PT20150914142544313_20181012103744_1.jpg"/>, <img alt="OMEGA K" src="/attach/image/201810/PT20150923094104820_20181012090932_1.jpg"/>, <img alt="OMEGA S" src="/attach/image/201810/PT20150914140712743_20181012100819_1.jpg"/>, <img alt="MICHELAN O2" src="/attach/image/201809/PT20150914150639203_20180928081640_1.jpg"/>, <img alt="MICHELAN C3" src="/attach/image/201809/PT20150914151034120_20180927165913_1.jpg"/>, <img alt="SW9000" src="/attach/image/201809/PT20170413182406327_20180927170412_1.jpg"/>, <img alt="SW6000Plus" src="/attach/image/201809/PT20150922111915610_2018092812
# ...

# %%
print(data[0])
print(data[0]['src'])
# Out:
# <img alt="LOTUS" src="/attach/image/201810/PT20170413184351273_20181012085230_1.jpg"/>
# /attach/image/201810/PT20170413184351273_20181012085230_1.jpg

# %%
# for img in soup.find_all('img'):
for img in soup.body.find_all('img'):
# for img in soup.body.div.find_all('img'):
# for img in soup.body.div.div.find_all('img'):
#     print(img.get('src'))
    print("https://www.semes.com"+img.get('src'))
# Out:
# https://www.semes.com/jsp/html/kor/image/common/logo.png
# https://www.semes.com/jsp/html/kor/image/common/btn_home.jpg
# https://www.semes.com/jsp/html/kor/image/common/btn_eng.jpg
# https://www.semes.com/jsp/html/kor/image/product/subvisual.png
# https://www.semes.com/jsp/html/kor/image/common/location_home.png
# https://www.semes.com/attach/image/201810/PT20170413184351273_20181012085230_1.jpg
# https://www.semes.com/attach/image/201810/PT20150914143022237_20181012110720_1.jpg
# https://www.semes.com/attach/image/201810/PT20150914142745747_20181012120537_1.jpg
# https://www.semes.com/attach/image/201810/PT20150923101251740_20181012113449_1.jpg
# https://www.semes.com/attach/image/201810/PT20150914142544313_20181012103744_1.jpg
# https://www.semes.com/attach/image/201810/PT20150923094104820_20181012090932_1.jpg
# https://www.semes.com/attach/image/201810/PT20150914140712743_20181012100819_1.jpg
# https://www.semes.com/attach/image/201809/PT20150914150639203_20180928081640_1.jpg
# ...
